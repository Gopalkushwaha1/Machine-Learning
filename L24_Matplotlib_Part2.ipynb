# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-b17ebaf0-cef5-4bf8-a90d-92dbd0996939" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b17ebaf0-cef5-4bf8-a90d-92dbd0996939">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
iris = pd.read_csv('iris.csv')

iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(iris['SepalLengthCm'], iris['SepalWidthCm'] , cmap='jet')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

plt.colorbar()

# %%
plt.scatter(iris['SepalLengthCm'], iris['SepalWidthCm'] , cmap='jet', alpha=0.7)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

plt.colorbar()

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2})

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 53    54            5.5           2.3            4.0           1.3        1
# 117  118            7.7           3.8            6.7           2.2        2
# 70    71            5.9           3.2            4.8           1.8        1
# 131  132            7.9           3.8            6.4           2.0        2
# 25    26            5.0           3.0            1.6           0.2        0

# %% [markdown]
# # Plot size

# %%
plt.figure(figsize=(15, 7))

plt.scatter(iris['SepalLengthCm'], iris['SepalWidthCm'] , cmap='jet')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

plt.colorbar()

# %% [markdown]
# # Annotations

# %%
batters = pd.read_csv('/content/batter (1).csv')

# %%
batters.shape
# Out:
# (605, 4)

# %%
sample_df = batters.head(100).sample(25,random_state=5)

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.figure(figsize=(15,7))

plt.scatter(sample_df['avg'], sample_df['strike_rate'])

for i in range(sample_df.shape[0]) :
  plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %%
x = [ 1,2,3,4]
y = [ 5,6,7,8]

plt.scatter(x,y)

plt.text(1,5 , 'Point 1')
plt.text(4,8 , 'Point 4')
# Out:
# Text(4, 8, 'Point 4')

# %% [markdown]
# # Horizontal and Vertical lines

# %%
plt.figure(figsize=(15,7))

plt.scatter(sample_df['avg'], sample_df['strike_rate'])

plt.axhline(130,color='red')
plt.axvline(25,color='green')

for i in range(sample_df.shape[0]) :
  plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %% [markdown]
# # Subplot

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
fig , ax = plt.subplots()

ax.scatter(sample_df['avg'], sample_df['strike_rate'])

ax.set_xlabel('Average')
ax.set_ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %%
# Batter dataset

fig , ax = plt.subplots(2,1 , figsize=(15,7))

ax[0].scatter(sample_df['strike_rate'], sample_df['avg'])

ax[0].set_xlabel('Average')
ax[0].set_ylabel('Strike Rate')


ax[1].scatter(sample_df['runs'], sample_df['avg'])

ax[1].set_xlabel('runs')
ax[1].set_ylabel('batter')

ax[0].set_title('Scatter Plot 1')
ax[1].set_title('Scatter Plot 2')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 2')

# %%
 sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
# Batter dataset

fig , ax = plt.subplots(2,1 , figsize=(15,7))

ax[0].scatter(sample_df['strike_rate'], sample_df['avg'])

ax[0].set_xlabel('Average')
ax[0].set_ylabel('Strike Rate')


ax[1].scatter(sample_df['runs'], sample_df['avg'])

ax[1].set_xlabel('runs')
ax[1].set_ylabel('batter')

ax[0].set_title('Scatter Plot 1')
ax[1].set_title('Scatter Plot 2')

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,1)
ax1.scatter(sample_df['strike_rate'], sample_df['avg'])

ax2 = fig.add_subplot(2,2,2)
ax2.scatter(sample_df['runs'], sample_df['avg'])

# %% [markdown]
# # 3D Scatter Plots

# %%
batters
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(batters['runs'],batters['avg'],batters['strike_rate'])

# %% [markdown]
# # 3D Line Plot

# %%
x = [0,1,5]
y = [0,10,13]
z = [ 0 , 13 , 20 ]

fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(x,y,z)

# %%
x = [0,1,5]
y = [0,10,13]
z = [ 0 , 13 , 20 ]

fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(x,y,z)
ax.plot3D(x,y,z,color='green')

# %% [markdown]
# # 3D Surface plot

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

# %%
xx , yy = np.meshgrid(x,y)

# %%
yy.shape
# Out:
# (100, 100)

# %%
z = xx**2 + yy**2
z.shape
# Out:
# (100, 100)

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.plot_surface(xx,yy,z)
