# %% [markdown]
# # Import library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load the data

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-5f28a4fd-c8b4-4230-add9-75a5bf7d55c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f28a4fd-c8b4-4230-add9-75a5bf7d55c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Looking the data

# %%
df = pd.read_csv('car_dataset.csv')

# %%
df = df.iloc[:, : -1]

# %%
df
# Out:
#          brand  km_drive      fule           owner  selling price
# 0        Honda     88374  Electric           First        1016667
# 1     Mercedes     49957  Electric          Second        2276914
# 2          BMW    131909    Hybrid  Fourth & Above         882917
# 3          BMW    186561    Diesel          Second        2666660
# 4    Chevrolet     89865  Electric  Fourth & Above        1272075
# ..         ...       ...       ...             ...            ...
# 195      Honda    111579    Petrol  Fourth & Above        2156004
# 196    Hyundai    195517    Hybrid          Second        2343558
# 197    Hyundai     90732    Petrol          Second        1606265
# 198       Ford    159165    Petrol           Third         182479
# 199   Mercedes    132500    Diesel          Second        1046593
#
# [200 rows x 5 columns]

# %%
df['brand'].value_counts()
# Out:
# brand
# Chevrolet     27
# Ford          25
# Toyota        22
# Honda         21
# Hyundai       20
# Nissan        20
# BMW           19
# Volkswagen    18
# Mercedes      16
# Kia           12
# Name: count, dtype: int64

# %%
df['brand'].nunique()
# Out:
# 10

# %% [markdown]
# # OHE using PANDAS

# %%
pd.get_dummies(df,columns=['fule','owner'])
# Out:
#          brand  km_drive  selling price  fule_Diesel  fule_Electric  \
# 0        Honda     88374        1016667        False           True
# 1     Mercedes     49957        2276914        False           True
# 2          BMW    131909         882917        False          False
# 3          BMW    186561        2666660         True          False
# 4    Chevrolet     89865        1272075        False           True
# ..         ...       ...            ...          ...            ...
# 195      Honda    111579        2156004        False          False
# 196    Hyundai    195517        2343558        False          False
# 197    Hyundai     90732        1606265        False          False
# 198       Ford    159165         182479        False          False
# 199   Mercedes    132500        1046593         True          False
#
#      fule_Hybrid  fule_Petrol  owner_First  owner_Fourth & Above  \
# 0          False        False         True                 False
# ...

# %% [markdown]
# # K -1 ONE ( remove 1st col for OHE)

# %%
pd.get_dummies(df,columns=['fule','owner'] , drop_first=True)
# Out:
#          brand  km_drive  selling price  fule_Electric  fule_Hybrid  \
# 0        Honda     88374        1016667           True        False
# 1     Mercedes     49957        2276914           True        False
# 2          BMW    131909         882917          False         True
# 3          BMW    186561        2666660          False        False
# 4    Chevrolet     89865        1272075           True        False
# ..         ...       ...            ...            ...          ...
# 195      Honda    111579        2156004          False        False
# 196    Hyundai    195517        2343558          False         True
# 197    Hyundai     90732        1606265          False        False
# 198       Ford    159165         182479          False        False
# 199   Mercedes    132500        1046593          False        False
#
#      fule_Petrol  owner_Fourth & Above  owner_Second  owner_Third
# 0          False                 False         False        False
# ...

# %% [markdown]
# # ONE USING Sklearn

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(df.iloc[:,0:4] , df.iloc[:,-1],test_size = 0.2 , random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # OHE With top categories

# %%
df.head()
# Out:
#        brand  km_drive      fule           owner  selling price
# 0      Honda     88374  Electric           First        1016667
# 1   Mercedes     49957  Electric          Second        2276914
# 2        BMW    131909    Hybrid  Fourth & Above         882917
# 3        BMW    186561    Diesel          Second        2666660
# 4  Chevrolet     89865  Electric  Fourth & Above        1272075

# %%
counts = df['brand'].value_counts()

# %%
counts
# Out:
# brand
# Chevrolet     27
# Ford          25
# Toyota        22
# Honda         21
# Hyundai       20
# Nissan        20
# BMW           19
# Volkswagen    18
# Mercedes      16
# Kia           12
# Name: count, dtype: int64

# %%
ohe = OneHotEncoder()

# %%
X_train_new = ohe.fit_transform(X_train[['fule','owner']]).toarray()

# %%
X_test_new = ohe.transform(X_test[['fule','owner']]).toarray()

# %%
X_train[['brand','km_drive']].values
# Out:
# array([['Mercedes', 169854],
#        ['Hyundai', 90732],
#        ['Ford', 91648],
#        ['Hyundai', 33426],
#        ['Toyota', 122151],
#        ['Honda', 111579],
#        ['Hyundai', 42369],
#        ['Hyundai', 172863],
#        ['Kia', 70414],
#        ['Honda', 161812],
#        ['Mercedes', 122474],
#        ['Nissan', 35060],
#        ['Ford', 194670],
#        ['Honda', 184482],
#        ['Ford', 127710],
#        ['Honda', 165419],
#        ['Chevrolet', 191875],
#        ['Honda', 25043],
#        ['Nissan', 20220],
#        ['Toyota', 60152],
#        ['Toyota', 29701],
#        ['Toyota', 93179],
#        ['Nissan', 167095],
#        ['Kia', 115152],
#        ['Mercedes', 23431],
#        ['Honda', 38513],
#        ['Mercedes', 85483],
#        ['Nissan', 173557],
#        ['Ford', 163025],
#        ['Ford', 156126],
#        ['Honda', 27319],
#        ['BMW', 164301],
#        ['Hyundai', 105756],
#        ['Chevrolet', 197880],
#        ['Volkswagen', 40518],
# ...

# %%
np.hstack((X_train[['brand','km_drive']].values,X_train_new)).shape
# Out:
# (160, 10)

# %% [markdown]
# # OHE with top Categories

# %%
df['brand'].value_counts()
# Out:
# brand
# Chevrolet     27
# Ford          25
# Toyota        22
# Honda         21
# Hyundai       20
# Nissan        20
# BMW           19
# Volkswagen    18
# Mercedes      16
# Kia           12
# Name: count, dtype: int64

# %%
rep = counts[counts <= 20].index

# %%
rep
# Out:
# Index(['Hyundai', 'Nissan', 'BMW', 'Volkswagen', 'Mercedes', 'Kia'], dtype='object', name='brand')

# %%
pd.get_dummies(df['brand'].replace(rep,'uncommon')).sample(5)
# Out:
#      Chevrolet   Ford  Honda  Toyota  uncommon
# 91       False  False  False   False      True
# 9         True  False  False   False     False
# 178      False  False  False   False      True
# 198      False   True  False   False     False
# 162      False  False  False   False      True
