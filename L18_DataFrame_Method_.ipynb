# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-0b0ac7ef-2061-4ec7-a562-7a291f22877d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b0ac7ef-2061-4ec7-a562-7a291f22877d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('car data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# Values count

marks = pd.DataFrame([
    [100,200,10],
    [200,230,12],
    [200,11,13],
    [300,123,21]
],columns = ['Physics','Chemistry','Maths']
)

# %%
marks
# Out:
#    Physics  Chemistry  Maths
# 0      100        200     10
# 1      200        230     12
# 2      200         11     13
# 3      300        123     21

# %%
a = pd.Series([1,2,3,4,5])

# %%
a.value_counts()
# Out:
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: count, dtype: int64

# %%
marks.value_counts()
# Out:
# Physics  Chemistry  Maths
# 100      200        10       1
# 200      11         13       1
#          230        12       1
# 300      123        21       1
# Name: count, dtype: int64

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car_name = df['Car_Name']

# %%
car_drive = df['Kms_Driven']

# %%
# Sort Value

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a.sort_values()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df.sort_values('Year')
# Out:
#                 Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 39                   sx4  2003           2.25           7.98       62000
# 37                   800  2003           0.35           2.28      127000
# 77               corolla  2004           1.50          12.35      135154
# 54                innova  2005           2.75          10.21       90000
# 189  Hero Super Splendor  2005           0.20           0.57       55000
# ..                   ...   ...            ...            ...         ...
# 27                 swift  2017           6.00           6.49       16200
# 268                 brio  2017           4.80           5.80       19000
# 2                   ciaz  2017           7.25           9.85        6900
# 299                 city  2017          11.50          12.50        9000
# 5          vitara brezza  2018           9.25           9.83        2071
#
#     Fuel_Type Seller_Type Transmission  Owner
# ...

# %%
# By default if we do sort on missing col then it keep in last

# %%
# Rank(Series)

k = df['Kms_Driven']

# %%
k
# Out:
# 0      27000
# 1      43000
# 2       6900
# 3       5200
# 4      42450
#        ...
# 296    33988
# 297    60000
# 298    87934
# 299     9000
# 300     5464
# Name: Kms_Driven, Length: 301, dtype: int64

# %%
k.rank()
# Out:
# 0      133.5
# 1      203.5
# 2       36.5
# 3       25.0
# 4      201.0
#        ...
# 296    158.0
# 297    260.5
# 298    288.0
# 299     45.0
# 300     27.0
# Name: Kms_Driven, Length: 301, dtype: float64

# %%
df['Kms_Driven'].rank(ascending=False)
# Out:
# 0      168.5
# 1       98.5
# 2      265.5
# 3      277.0
# 4      101.0
#        ...
# 296    144.0
# 297     41.5
# 298     14.0
# 299    257.0
# 300    275.0
# Name: Kms_Driven, Length: 301, dtype: float64

# %%
marks.sort_index()
# Out:
#    Physics  Chemistry  Maths
# 0      100        200     10
# 1      200        230     12
# 2      200         11     13
# 3      300        123     21

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.sort_index(ascending=False)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 300     brio  2016           5.30           5.90        5464    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 298     city  2009           3.35          11.00       87934    Petrol
# 297     brio  2015           4.00           5.90       60000    Petrol
# 296     city  2016           9.50          11.60       33988    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 4      swift  2014           4.60           6.87       42450    Diesel
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 0       ritz  2014           3.35           5.59       27000    Petrol
#
#     Seller_Type Transmission  Owner
# 300      Dealer       Manual      0
# 299      Dealer       Manual      0
# ...

# %%
# Set Index ( DataFrame) --> Inplace
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.set_index('Car_Name')
# Out:
#           Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# ritz      2014           3.35           5.59       27000    Petrol
# sx4       2013           4.75           9.54       43000    Diesel
# ciaz      2017           7.25           9.85        6900    Petrol
# wagon r   2011           2.85           4.15        5200    Petrol
# swift     2014           4.60           6.87       42450    Diesel
# ...        ...            ...            ...         ...       ...
# city      2016           9.50          11.60       33988    Diesel
# brio      2015           4.00           5.90       60000    Petrol
# city      2009           3.35          11.00       87934    Petrol
# city      2017          11.50          12.50        9000    Diesel
# brio      2016           5.30           5.90        5464    Petrol
#
#          Seller_Type Transmission  Owner
# Car_Name
# ritz          Dealer       Manual      0
# sx4           Dealer       Manual      0
# ...

# %%
# Reset Index -> Just reverse of set index ( It back to default index )

# %%
df.reset_index()
# Out:
#      index Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0        0     ritz  2014           3.35           5.59       27000    Petrol
# 1        1      sx4  2013           4.75           9.54       43000    Diesel
# 2        2     ciaz  2017           7.25           9.85        6900    Petrol
# 3        3  wagon r  2011           2.85           4.15        5200    Petrol
# 4        4    swift  2014           4.60           6.87       42450    Diesel
# ..     ...      ...   ...            ...            ...         ...       ...
# 296    296     city  2016           9.50          11.60       33988    Diesel
# 297    297     brio  2015           4.00           5.90       60000    Petrol
# 298    298     city  2009           3.35          11.00       87934    Petrol
# 299    299     city  2017          11.50          12.50        9000    Diesel
# 300    300     brio  2016           5.30           5.90        5464    Petrol
#
# ...

# %%
# Rename (Dataframe) -> Index

df.set_index('Year',inplace=True)

# %%
df
# Out:
#      Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59       27000    Petrol      Dealer
# 2013      sx4           4.75           9.54       43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85        6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15        5200    Petrol      Dealer
# 2014    swift           4.60           6.87       42450    Diesel      Dealer
# ...       ...            ...            ...         ...       ...         ...
# 2016     city           9.50          11.60       33988    Diesel      Dealer
# 2015     brio           4.00           5.90       60000    Petrol      Dealer
# 2009     city           3.35          11.00       87934    Petrol      Dealer
# 2017     city          11.50          12.50        9000    Diesel      Dealer
# 2016     brio           5.30           5.90        5464    Petrol      Dealer
#
#      Transmission  Owner
# ...

# %%
df.rename(columns={'Car_Name':'Name' ,'Kms_Driven':'Kms'},inplace = True)

# %%
df
# Out:
#          Name  Selling_Price  Present_Price    Kms Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59  27000    Petrol      Dealer
# 2013      sx4           4.75           9.54  43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85   6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15   5200    Petrol      Dealer
# 2014    swift           4.60           6.87  42450    Diesel      Dealer
# ...       ...            ...            ...    ...       ...         ...
# 2016     city           9.50          11.60  33988    Diesel      Dealer
# 2015     brio           4.00           5.90  60000    Petrol      Dealer
# 2009     city           3.35          11.00  87934    Petrol      Dealer
# 2017     city          11.50          12.50   9000    Diesel      Dealer
# 2016     brio           5.30           5.90   5464    Petrol      Dealer
#
#      Transmission  Owner
# Year
# 2014       Manual      0
# 2013       Manual      0
# ...

# %%
# Unique (Series)

a.unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
# isnull(Series + DataFrame)

df['Owner'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Name             0
# Selling_Price    0
# Present_Price    0
# Kms              0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# notnull ( Series + DataFrame)

df['Owner'].notnull().sum()
# Out:
# np.int64(301)

# %%
df.notnull().sum()
# Out:
# Name             301
# Selling_Price    301
# Present_Price    301
# Kms              301
# Fuel_Type        301
# Seller_Type      301
# Transmission     301
# Owner            301
# dtype: int64

# %%
# Has nan ( Series + DataFrame )   -> Check is there any missing value

df['Owner'].hasnans
# Out:
# False

# %%
df['Kms'].dropna()
# Out:
# Year
# 2014    27000
# 2013    43000
# 2017     6900
# 2011     5200
# 2014    42450
#         ...
# 2016    33988
# 2015    60000
# 2009    87934
# 2017     9000
# 2016     5464
# Name: Kms, Length: 301, dtype: int64

# %%
df.dropna()
# Out:
#          Name  Selling_Price  Present_Price    Kms Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59  27000    Petrol      Dealer
# 2013      sx4           4.75           9.54  43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85   6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15   5200    Petrol      Dealer
# 2014    swift           4.60           6.87  42450    Diesel      Dealer
# ...       ...            ...            ...    ...       ...         ...
# 2016     city           9.50          11.60  33988    Diesel      Dealer
# 2015     brio           4.00           5.90  60000    Petrol      Dealer
# 2009     city           3.35          11.00  87934    Petrol      Dealer
# 2017     city          11.50          12.50   9000    Diesel      Dealer
# 2016     brio           5.30           5.90   5464    Petrol      Dealer
#
#      Transmission  Owner
# Year
# 2014       Manual      0
# 2013       Manual      0
# ...

# %%
# Filling missing value with fillna         ( Series + DataFrame )

df['Owner'].fillna('Unknown')
# Out:
# Year
# 2014    0
# 2013    0
# 2017    0
# 2011    0
# 2014    0
#        ..
# 2016    0
# 2015    0
# 2009    0
# 2017    0
# 2016    0
# Name: Owner, Length: 301, dtype: int64

# %%
df
# Out:
#          Name  Selling_Price  Present_Price    Kms Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59  27000    Petrol      Dealer
# 2013      sx4           4.75           9.54  43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85   6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15   5200    Petrol      Dealer
# 2014    swift           4.60           6.87  42450    Diesel      Dealer
# ...       ...            ...            ...    ...       ...         ...
# 2016     city           9.50          11.60  33988    Diesel      Dealer
# 2015     brio           4.00           5.90  60000    Petrol      Dealer
# 2009     city           3.35          11.00  87934    Petrol      Dealer
# 2017     city          11.50          12.50   9000    Diesel      Dealer
# 2016     brio           5.30           5.90   5464    Petrol      Dealer
#
#      Transmission  Owner
# Year
# 2014       Manual      0
# 2013       Manual      0
# ...

# %%
df.fillna(0)
# Out:
#          Name  Selling_Price  Present_Price    Kms Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59  27000    Petrol      Dealer
# 2013      sx4           4.75           9.54  43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85   6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15   5200    Petrol      Dealer
# 2014    swift           4.60           6.87  42450    Diesel      Dealer
# ...       ...            ...            ...    ...       ...         ...
# 2016     city           9.50          11.60  33988    Diesel      Dealer
# 2015     brio           4.00           5.90  60000    Petrol      Dealer
# 2009     city           3.35          11.00  87934    Petrol      Dealer
# 2017     city          11.50          12.50   9000    Diesel      Dealer
# 2016     brio           5.30           5.90   5464    Petrol      Dealer
#
#      Transmission  Owner
# Year
# 2014       Manual      0
# 2013       Manual      0
# ...

# %%
df['Name'].fillna(method = 'ffill')
# Out:
# /tmp/ipython-input-1818830353.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Name'].fillna(method = 'ffill')
# Year
# 2014       ritz
# 2013        sx4
# 2017       ciaz
# 2011    wagon r
# 2014      swift
#          ...
# 2016       city
# 2015       brio
# 2009       city
# 2017       city
# 2016       brio
# Name: Name, Length: 301, dtype: object

# %%
df
# Out:
#          Name  Selling_Price  Present_Price    Kms Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59  27000    Petrol      Dealer
# 2013      sx4           4.75           9.54  43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85   6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15   5200    Petrol      Dealer
# 2014    swift           4.60           6.87  42450    Diesel      Dealer
# ...       ...            ...            ...    ...       ...         ...
# 2016     city           9.50          11.60  33988    Diesel      Dealer
# 2015     brio           4.00           5.90  60000    Petrol      Dealer
# 2009     city           3.35          11.00  87934    Petrol      Dealer
# 2017     city          11.50          12.50   9000    Diesel      Dealer
# 2016     brio           5.30           5.90   5464    Petrol      Dealer
#
#      Transmission  Owner
# Year
# 2014       Manual      0
# 2013       Manual      0
# ...

# %%
# Drop_Duplicate ( Series + DataFrane )   -> to show how much data is duplicate

car = df['Name']

# %%
car.duplicated().sum()
# Out:
# np.int64(203)

# %%
car = car.drop_duplicates()

# %%
car
# Out:
# Year
# 2014       ritz
# 2013        sx4
# 2017       ciaz
# 2011    wagon r
# 2014      swift
#          ...
# 2012      verna
# 2013       city
# 2015       brio
# 2014      amaze
# 2016       jazz
# Name: Name, Length: 98, dtype: object

# %%
df.duplicated()
# Out:
# Year
# 2014    False
# 2013    False
# 2017    False
# 2011    False
# 2014    False
#         ...
# 2016    False
# 2015    False
# 2009    False
# 2017    False
# 2016    False
# Length: 301, dtype: bool

# %%
df.drop_duplicates()
# Out:
#          Name  Selling_Price  Present_Price    Kms Fuel_Type Seller_Type  \
# Year
# 2014     ritz           3.35           5.59  27000    Petrol      Dealer
# 2013      sx4           4.75           9.54  43000    Diesel      Dealer
# 2017     ciaz           7.25           9.85   6900    Petrol      Dealer
# 2011  wagon r           2.85           4.15   5200    Petrol      Dealer
# 2014    swift           4.60           6.87  42450    Diesel      Dealer
# ...       ...            ...            ...    ...       ...         ...
# 2016     city           9.50          11.60  33988    Diesel      Dealer
# 2015     brio           4.00           5.90  60000    Petrol      Dealer
# 2009     city           3.35          11.00  87934    Petrol      Dealer
# 2017     city          11.50          12.50   9000    Diesel      Dealer
# 2016     brio           5.30           5.90   5464    Petrol      Dealer
#
#      Transmission  Owner
# Year
# 2014       Manual      0
# 2013       Manual      0
# ...

# %%
# drop (Series + DataFrame)

df.drop('Seller_Type',axis=1 , inplace=True)

# %%
df
# Out:
#          Name  Selling_Price  Present_Price    Kms Fuel_Type Transmission  \
# Year
# 2014     ritz           3.35           5.59  27000    Petrol       Manual
# 2013      sx4           4.75           9.54  43000    Diesel       Manual
# 2017     ciaz           7.25           9.85   6900    Petrol       Manual
# 2011  wagon r           2.85           4.15   5200    Petrol       Manual
# 2014    swift           4.60           6.87  42450    Diesel       Manual
# ...       ...            ...            ...    ...       ...          ...
# 2016     city           9.50          11.60  33988    Diesel       Manual
# 2015     brio           4.00           5.90  60000    Petrol       Manual
# 2009     city           3.35          11.00  87934    Petrol       Manual
# 2017     city          11.50          12.50   9000    Diesel       Manual
# 2016     brio           5.30           5.90   5464    Petrol       Manual
#
#       Owner
# Year
# 2014      0
# 2013      0
# 2017      0
# ...

# %%
# drop (Series + DataFrame)

df.drop('Selling_Price',axis=1 , inplace=True)

# %%
df
# Out:
#          Name  Present_Price    Kms Fuel_Type Transmission  Owner
# Year
# 2014     ritz           5.59  27000    Petrol       Manual      0
# 2013      sx4           9.54  43000    Diesel       Manual      0
# 2017     ciaz           9.85   6900    Petrol       Manual      0
# 2011  wagon r           4.15   5200    Petrol       Manual      0
# 2014    swift           6.87  42450    Diesel       Manual      0
# ...       ...            ...    ...       ...          ...    ...
# 2016     city          11.60  33988    Diesel       Manual      0
# 2015     brio           5.90  60000    Petrol       Manual      0
# 2009     city          11.00  87934    Petrol       Manual      0
# 2017     city          12.50   9000    Diesel       Manual      0
# 2016     brio           5.90   5464    Petrol       Manual      0
#
# [301 rows x 6 columns]

# %%
# Apply (Series + Dataframe )

df['Kms'].apply(lambda x : x/1000)
# Out:
# Year
# 2014    27.000
# 2013    43.000
# 2017     6.900
# 2011     5.200
# 2014    42.450
#          ...
# 2016    33.988
# 2015    60.000
# 2009    87.934
# 2017     9.000
# 2016     5.464
# Name: Kms, Length: 301, dtype: float64
